# %% [markdown]
# # Car Price Prediction::

# %% [markdown]
# Download dataset from this link:
#
# https://www.kaggle.com/hellbuoy/car-price-prediction

# %% [markdown]
# # Problem Statement::

# %%
# mount google drive in to your Colab enviornment
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Jawad_AI_Assignments/
# Out:
# /content/drive/MyDrive/Jawad_AI_Assignments

# %% [markdown]
# A Chinese automobile company Geely Auto aspires to enter the US market by setting up their manufacturing unit there and producing cars locally to give competition to their US and European counterparts.
#
# They have contracted an automobile consulting company to understand the factors on which the pricing of cars depends. Specifically, they want to understand the factors affecting the pricing of cars in the American market, since those may be very different from the Chinese market. The company wants to know:
#
# Which variables are significant in predicting the price of a car
# How well those variables describe the price of a car
# Based on various market surveys, the consulting firm has gathered a large data set of different types of cars across the America market.
#
# # task::
# We are required to model the price of cars with the available independent variables. It will be used by the management to understand how exactly the prices vary with the independent variables. They can accordingly manipulate the design of the cars, the business strategy etc. to meet certain price levels. Further, the model will be a good way for management to understand the pricing dynamics of a new market.

# %% [markdown]
# # WORKFLOW ::

# %% [markdown]
# 1.Load Data
#
# 2.Check Missing Values ( If Exist ; Fill each record with mean of its feature )
#
# 3.Split into 50% Training(Samples,Labels) , 30% Test(Samples,Labels) and 20% Validation Data(Samples,Labels).
#
# 4.Model : input Layer (No. of features ), 3 hidden layers including 10,8,6 unit & Output Layer with activation function relu/tanh (check by experiment).
#
# 5.Compilation Step (Note : Its a Regression problem , select loss , metrics according to it)
# 6.Train the Model with Epochs (100) and validate it
#
# 7.If the model gets overfit tune your model by changing the units , No. of layers , activation function , epochs , add dropout layer or add Regularizer according to the need .
#
# 8.Evaluation Step
#
# 9.Prediction

# %%
import pandas as pd
import numpy as np
car_data = pd.read_csv('/content/drive/MyDrive/Jawad_AI_Assignments/CarPrice_Assignment.csv')

# %%
import tensorflow as tf

# %%
car_data.head()
# Out:
#    car_ID  symboling                   CarName  ... citympg highwaympg    price
# 0       1          3        alfa-romero giulia  ...      21         27  13495.0
# 1       2          3       alfa-romero stelvio  ...      21         27  16500.0
# 2       3          1  alfa-romero Quadrifoglio  ...      19         26  16500.0
# 3       4          2               audi 100 ls  ...      24         30  13950.0
# 4       5          2                audi 100ls  ...      18         22  17450.0
#
# [5 rows x 26 columns]

# %%
car_data['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
#        'mazda glc deluxe', 'mazda 626', 'mazda glc', 'mazda rx-7 gs',
#        'mazda glc 4', 'mazda glc custom l', 'mazda glc custom',
#        'buick electra 225 custom', 'buick century luxus (sw)',
#        'buick century', 'buick skyhawk', 'buick opel isuzu deluxe',
#        'buick skylark', 'buick century special',
#        'buick regal sport coupe (turbo)', 'mercury cougar',
#        'mitsubishi mirage', 'mitsubishi lancer', 'mitsubishi outlander',
#        'mitsubishi g4', 'mitsubishi mirage g4', 'mitsubishi montero',
#        'mitsubishi pajero', 'Nissan versa', 'nissan gt-r', 'nissan rogue',
#        'nissan latio', 'nissan titan', 'nissan leaf', 'nissan juke',
#        'nissan note', 'nissan clipper', 'nissan nv200', 'nissan dayz',
#        'nissan fuga', 'nissan otti', 'nissan teana', 'nissan kicks',
#        'peugeot 504', 'peugeot 304', 'peugeot 504 (sw)', 'peugeot 604sl',
#        'peugeot 505s turbo diesel', 'plymouth fury iii',
#        'plymouth cricket', 'plymouth satellite custom (sw)',
#        'plymouth fury gran sedan', 'plymouth valiant', 'plymouth duster',
#        'porsche macan', 'porcshce panamera', 'porsche cayenne',
#        'porsche boxter', 'renault 12tl', 'renault 5 gtl', 'saab 99e',
#        'saab 99le', 'saab 99gle', 'subaru', 'subaru dl', 'subaru brz',
#        'subaru baja', 'subaru r1', 'subaru r2', 'subaru trezia',
#        'subaru tribeca', 'toyota corona mark ii', 'toyota corona',
#        'toyota corolla 1200', 'toyota corona hardtop',
#        'toyota corolla 1600 (sw)', 'toyota carina', 'toyota mark ii',
#        'toyota corolla', 'toyota corolla liftback',
#        'toyota celica gt liftback', 'toyota corolla tercel',
#        'toyota corona liftback', 'toyota starlet', 'toyota tercel',
#        'toyota cressida', 'toyota celica gt', 'toyouta tercel',
#        'vokswagen rabbit', 'volkswagen 1131 deluxe sedan',
#        'volkswagen model 111', 'volkswagen type 3', 'volkswagen 411 (sw)',
#        'volkswagen super beetle', 'volkswagen dasher', 'vw dasher',
#        'vw rabbit', 'volkswagen rabbit', 'volkswagen rabbit custom',
#        'volvo 145e (sw)', 'volvo 144ea', 'volvo 244dl', 'volvo 245',
#        'volvo 264gl', 'volvo diesel', 'volvo 246'], dtype=object)

# %%
#check if there are empty cells, if there are then row and column indexes will be returned where values are empty or missing
np.where(car_data.applymap(lambda x: x ==''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
car_data.isnull().any()
# Out:
# car_ID              False
# symboling           False
# CarName             False
# fueltype            False
# aspiration          False
# doornumber          False
# carbody             False
# drivewheel          False
# enginelocation      False
# wheelbase           False
# carlength           False
# carwidth            False
# carheight           False
# curbweight          False
# enginetype          False
# cylindernumber      False
# enginesize          False
# fuelsystem          False
# boreratio           False
# stroke              False
# compressionratio    False
# horsepower          False
# peakrpm             False
# citympg             False
# highwaympg          False
# price               False
# dtype: bool

# %%
# correct the name error in audi 100 ls
car_data.iloc[3,2] = 'audi 100ls'

# %%
car_data.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
car_data.drop(columns=['car_ID'], inplace = True)

# %%
# get columns so that we can use the column names for onehot encoding of catagorical featrues in next cell
car_data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
# onehot encode all catagorical columns
final_car = pd.get_dummies(car_data, columns=['CarName','symboling','fueltype',	'aspiration',	'doornumber',	'carbody',	'drivewheel',	'enginelocation',	'enginetype',	'cylindernumber',	'fuelsystem'], drop_first = True)

# %%
final_car.head()
# Out:
#    car_ID  wheelbase  ...  fuelsystem_spdi  fuelsystem_spfi
# 0       1       88.6  ...                0                0
# 1       2       88.6  ...                0                0
# 2       3       94.5  ...                0                0
# 3       4       99.8  ...                0                0
# 4       5       99.4  ...                0                0
#
# [5 rows x 194 columns]

# %%
#check statistical data to see abnormal values and outliers
final_car.describe()
# Out:
#            car_ID   wheelbase  ...  fuelsystem_spdi  fuelsystem_spfi
# count  205.000000  205.000000  ...       205.000000       205.000000
# mean   103.000000   98.756585  ...         0.043902         0.004878
# std     59.322565    6.021776  ...         0.205380         0.069843
# min      1.000000   86.600000  ...         0.000000         0.000000
# 25%     52.000000   94.500000  ...         0.000000         0.000000
# 50%    103.000000   97.000000  ...         0.000000         0.000000
# 75%    154.000000  102.400000  ...         0.000000         0.000000
# max    205.000000  120.900000  ...         1.000000         1.000000
#
# [8 rows x 194 columns]

# %%
#initialize a seed value so that each time we can get the same random number sequence, it will help us  as a team
# working on a common project to work on the same random data. Each new seed will generate a particular sequnce
#of random number. You can choose any seed value here of your choice
# 0.72 means we have taken 72% values for training set as we will make 72/4 = 18 rows of k fold validation data, where
# value of k will be 4 when we compile and fit our model for validation
np.random.seed(11111)
msk = np.random.rand(len(final_car)) < 0.72
train_total = final_car[msk]
test_total = final_car[~msk]

# %%
#check the length of our test and train datasets
print(len(train_total))
print(len(test_total))
# Out:
# 141
# 64

# %%
train_total.head(10)
# Out:
#     car_ID  wheelbase  ...  fuelsystem_spdi  fuelsystem_spfi
# 1        2       88.6  ...                0                0
# 2        3       94.5  ...                0                0
# 3        4       99.8  ...                0                0
# 4        5       99.4  ...                0                0
# 5        6       99.8  ...                0                0
# 6        7      105.8  ...                0                0
# 7        8      105.8  ...                0                0
# 8        9      105.8  ...                0                0
# 9       10       99.5  ...                0                0
# 11      12      101.2  ...                0                0
#
# [10 rows x 194 columns]

# %%
# check statistical overview if there are some outliers and abnormal values
train_total.describe()
# Out:
#            car_ID   wheelbase  ...  fuelsystem_spdi  fuelsystem_spfi
# count  141.000000  141.000000  ...       141.000000       141.000000
# mean    99.780142   98.692199  ...         0.035461         0.007092
# std     59.881322    6.005665  ...         0.185601         0.084215
# min      2.000000   86.600000  ...         0.000000         0.000000
# 25%     49.000000   94.500000  ...         0.000000         0.000000
# 50%     98.000000   96.500000  ...         0.000000         0.000000
# 75%    150.000000  102.400000  ...         0.000000         0.000000
# max    205.000000  115.600000  ...         1.000000         1.000000
#
# [8 rows x 194 columns]

# %%
print(train_total.dtypes)
# Out:
# car_ID               int64
# wheelbase          float64
# carlength          float64
# carwidth           float64
# carheight          float64
#                     ...
# fuelsystem_idi       uint8
# fuelsystem_mfi       uint8
# fuelsystem_mpfi      uint8
# fuelsystem_spdi      uint8
# fuelsystem_spfi      uint8
# Length: 194, dtype: object

# %%
# get our price labels and store in another dataframe
train_label = train_total.loc[:,'price']
test_label = test_total.loc[:,'price']

# %%
train_label
# Out:
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
#         ...
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, Length: 141, dtype: float64

# %%
# drop price from oroginal training and test dataset , as price is not needed there
test_data= test_total.drop(columns = ['price'])
train_data= train_total.drop(columns = ['price'])

# %%
train_data.shape
# Out:
# (141, 193)

# %%
train_data
# Out:
#      car_ID  wheelbase  ...  fuelsystem_spdi  fuelsystem_spfi
# 1         2       88.6  ...                0                0
# 2         3       94.5  ...                0                0
# 3         4       99.8  ...                0                0
# 4         5       99.4  ...                0                0
# 5         6       99.8  ...                0                0
# ..      ...        ...  ...              ...              ...
# 200     201      109.1  ...                0                0
# 201     202      109.1  ...                0                0
# 202     203      109.1  ...                0                0
# 203     204      109.1  ...                0                0
# 204     205      109.1  ...                0                0
#
# [141 rows x 193 columns]

# %%
#get indices of the columns so that we can know how many columns we have to normalize, as catagorical columns which we
# have added with onehot encoding, do not need to be normalized.. normalizing will be done in next cell
{train_data.columns.get_loc(c): c for idx, c in enumerate(train_data.columns)}
# Out:
# {0: 'car_ID',
#  1: 'wheelbase',
#  2: 'carlength',
#  3: 'carwidth',
#  4: 'carheight',
#  5: 'curbweight',
#  6: 'enginesize',
#  7: 'boreratio',
#  8: 'stroke',
#  9: 'compressionratio',
#  10: 'horsepower',
#  11: 'peakrpm',
#  12: 'citympg',
#  13: 'highwaympg',
#  14: 'CarName_alfa-romero Quadrifoglio',
#  15: 'CarName_alfa-romero giulia',
#  16: 'CarName_alfa-romero stelvio',
#  17: 'CarName_audi 100ls',
#  18: 'CarName_audi 4000',
#  19: 'CarName_audi 5000',
#  20: 'CarName_audi 5000s (diesel)',
#  21: 'CarName_audi fox',
#  22: 'CarName_bmw 320i',
#  23: 'CarName_bmw x1',
#  24: 'CarName_bmw x3',
#  25: 'CarName_bmw x4',
#  26: 'CarName_bmw x5',
#  27: 'CarName_bmw z4',
#  28: 'CarName_buick century',
#  29: 'CarName_buick century luxus (sw)',
#  30: 'CarName_buick century special',
#  31: 'CarName_buick electra 225 custom',
#  32: 'CarName_buick opel isuzu deluxe',
#  33: 'CarName_buick regal sport coupe (turbo)',
#  34: 'CarName_buick skyhawk',
#  35: 'CarName_buick skylark',
#  36: 'CarName_chevrolet impala',
#  37: 'CarName_chevrolet monte carlo',
#  38: 'CarName_chevrolet vega 2300',
#  39: 'CarName_dodge challenger se',
#  40: 'CarName_dodge colt (sw)',
#  41: 'CarName_dodge colt hardtop',
#  42: 'CarName_dodge coronet custom',
#  43: 'CarName_dodge coronet custom (sw)',
#  44: 'CarName_dodge d200',
#  45: 'CarName_dodge dart custom',
#  46: 'CarName_dodge monaco (sw)',
#  47: 'CarName_dodge rampage',
#  48: 'CarName_honda accord',
#  49: 'CarName_honda accord cvcc',
#  50: 'CarName_honda accord lx',
#  51: 'CarName_honda civic',
#  52: 'CarName_honda civic (auto)',
#  53: 'CarName_honda civic 1300',
#  54: 'CarName_honda civic 1500 gl',
#  55: 'CarName_honda civic cvcc',
#  56: 'CarName_honda prelude',
#  57: 'CarName_isuzu D-Max ',
#  58: 'CarName_isuzu D-Max V-Cross',
#  59: 'CarName_isuzu MU-X',
#  60: 'CarName_jaguar xf',
#  61: 'CarName_jaguar xj',
#  62: 'CarName_jaguar xk',
#  63: 'CarName_maxda glc deluxe',
#  64: 'CarName_maxda rx3',
#  65: 'CarName_mazda 626',
#  66: 'CarName_mazda glc',
#  67: 'CarName_mazda glc 4',
#  68: 'CarName_mazda glc custom',
#  69: 'CarName_mazda glc custom l',
#  70: 'CarName_mazda glc deluxe',
#  71: 'CarName_mazda rx-4',
#  72: 'CarName_mazda rx-7 gs',
#  73: 'CarName_mazda rx2 coupe',
#  74: 'CarName_mercury cougar',
#  75: 'CarName_mitsubishi g4',
#  76: 'CarName_mitsubishi lancer',
#  77: 'CarName_mitsubishi mirage',
#  78: 'CarName_mitsubishi mirage g4',
#  79: 'CarName_mitsubishi montero',
#  80: 'CarName_mitsubishi outlander',
#  81: 'CarName_mitsubishi pajero',
#  82: 'CarName_nissan clipper',
#  83: 'CarName_nissan dayz',
#  84: 'CarName_nissan fuga',
#  85: 'CarName_nissan gt-r',
#  86: 'CarName_nissan juke',
#  87: 'CarName_nissan kicks',
#  88: 'CarName_nissan latio',
#  89: 'CarName_nissan leaf',
#  90: 'CarName_nissan note',
#  91: 'CarName_nissan nv200',
#  92: 'CarName_nissan otti',
#  93: 'CarName_nissan rogue',
#  94: 'CarName_nissan teana',
#  95: 'CarName_nissan titan',
#  96: 'CarName_peugeot 304',
#  97: 'CarName_peugeot 504',
#  98: 'CarName_peugeot 504 (sw)',
#  99: 'CarName_peugeot 505s turbo diesel',
#  100: 'CarName_peugeot 604sl',
#  101: 'CarName_plymouth cricket',
#  102: 'CarName_plymouth duster',
#  103: 'CarName_plymouth fury gran sedan',
#  104: 'CarName_plymouth fury iii',
#  105: 'CarName_plymouth satellite custom (sw)',
#  106: 'CarName_plymouth valiant',
#  107: 'CarName_porcshce panamera',
#  108: 'CarName_porsche boxter',
#  109: 'CarName_porsche cayenne',
#  110: 'CarName_porsche macan',
#  111: 'CarName_renault 12tl',
#  112: 'CarName_renault 5 gtl',
#  113: 'CarName_saab 99e',
#  114: 'CarName_saab 99gle',
#  115: 'CarName_saab 99le',
#  116: 'CarName_subaru',
#  117: 'CarName_subaru baja',
#  118: 'CarName_subaru brz',
#  119: 'CarName_subaru dl',
#  120: 'CarName_subaru r1',
#  121: 'CarName_subaru r2',
#  122: 'CarName_subaru trezia',
#  123: 'CarName_subaru tribeca',
#  124: 'CarName_toyota carina',
#  125: 'CarName_toyota celica gt',
#  126: 'CarName_toyota celica gt liftback',
#  127: 'CarName_toyota corolla',
#  128: 'CarName_toyota corolla 1200',
#  129: 'CarName_toyota corolla 1600 (sw)',
#  130: 'CarName_toyota corolla liftback',
#  131: 'CarName_toyota corolla tercel',
#  132: 'CarName_toyota corona',
#  133: 'CarName_toyota corona hardtop',
#  134: 'CarName_toyota corona liftback',
#  135: 'CarName_toyota corona mark ii',
#  136: 'CarName_toyota cressida',
#  137: 'CarName_toyota mark ii',
#  138: 'CarName_toyota starlet',
#  139: 'CarName_toyota tercel',
#  140: 'CarName_toyouta tercel',
#  141: 'CarName_vokswagen rabbit',
#  142: 'CarName_volkswagen 1131 deluxe sedan',
#  143: 'CarName_volkswagen 411 (sw)',
#  144: 'CarName_volkswagen dasher',
#  145: 'CarName_volkswagen model 111',
#  146: 'CarName_volkswagen rabbit',
#  147: 'CarName_volkswagen rabbit custom',
#  148: 'CarName_volkswagen super beetle',
#  149: 'CarName_volkswagen type 3',
#  150: 'CarName_volvo 144ea',
#  151: 'CarName_volvo 145e (sw)',
#  152: 'CarName_volvo 244dl',
#  153: 'CarName_volvo 245',
#  154: 'CarName_volvo 246',
#  155: 'CarName_volvo 264gl',
#  156: 'CarName_volvo diesel',
#  157: 'CarName_vw dasher',
#  158: 'CarName_vw rabbit',
#  159: 'symboling_-1',
#  160: 'symboling_0',
#  161: 'symboling_1',
#  162: 'symboling_2',
#  163: 'symboling_3',
#  164: 'fueltype_gas',
#  165: 'aspiration_turbo',
#  166: 'doornumber_two',
#  167: 'carbody_hardtop',
#  168: 'carbody_hatchback',
#  169: 'carbody_sedan',
#  170: 'carbody_wagon',
#  171: 'drivewheel_fwd',
#  172: 'drivewheel_rwd',
#  173: 'enginelocation_rear',
#  174: 'enginetype_dohcv',
#  175: 'enginetype_l',
#  176: 'enginetype_ohc',
#  177: 'enginetype_ohcf',
#  178: 'enginetype_ohcv',
#  179: 'enginetype_rotor',
#  180: 'cylindernumber_five',
#  181: 'cylindernumber_four',
#  182: 'cylindernumber_six',
#  183: 'cylindernumber_three',
#  184: 'cylindernumber_twelve',
#  185: 'cylindernumber_two',
#  186: 'fuelsystem_2bbl',
#  187: 'fuelsystem_4bbl',
#  188: 'fuelsystem_idi',
#  189: 'fuelsystem_mfi',
#  190: 'fuelsystem_mpfi',
#  191: 'fuelsystem_spdi',
#  192: 'fuelsystem_spfi'}

# %%
## we normalize data because data has big vlaues in decimal and it will worsen performance of our model, may overfit 
## or  we may face hardware resource high usage
# we will apply the formula normalized_train_data = (train_data - mean)/ stadrad_deviation
## firt take mean of training, then subtract mean from each value of the array slice train_data.iloc[:,0:13]
mean = train_data.iloc[:,0:13].mean(axis=0) # taking the mean of 
train_data.iloc[:,0:13] -= mean
std = train_data.iloc[:,0:13].std(axis=0)
train_data.iloc[:,0:13] /= std
test_data.iloc[:,0:13] -= mean
test_data.iloc[:,0:13] /= std

# %%
mean
# Out:
# car_ID                99.780142
# wheelbase             98.692199
# carlength            173.658156
# carwidth              65.875887
# carheight             53.648227
# curbweight          2546.787234
# enginesize           125.666667
# boreratio              3.324184
# stroke                 3.256809
# compressionratio      10.070355
# horsepower           103.702128
# peakrpm             5143.971631
# citympg               25.113475
# dtype: float64

# %%
std
# Out:
# car_ID               59.881322
# wheelbase             6.005665
# carlength            12.320089
# carwidth              2.188604
# carheight             2.508204
# curbweight          529.769152
# enginesize           41.733451
# boreratio             0.266123
# stroke                0.296387
# compressionratio      3.868579
# horsepower           38.424275
# peakrpm             474.472458
# citympg               6.509435
# dtype: float64

# %%
mean_label = train_label.mean()
train_label -= mean_label
std_label = train_label.std()
train_label /= std_label
test_label -= mean_label
test_label /= std_label

# %%
mean_label
# Out:
# 13379.132390070921

# %%
std_label
# Out:
# 8189.4945680106175

# %%
print(mean_label)
# Out:
# 13379.132390070921

# %%
test_label
# Out:
# 0      0.014148
# 10     0.372534
# 14     1.365880
# 15     2.122337
# 18    -1.004718
#          ...
# 192    0.056886
# 193   -0.132991
# 194   -0.053621
# 196    0.318196
# 198    0.615529
# Name: price, Length: 64, dtype: float64

# %%
train_data.shape
# Out:
# (141, 193)

# %%
#store in numpy array

# %%
test = np.array(test_data.iloc[:]).astype('float32')

# %%
train = np.array(train_data.iloc[:]).astype('float32')

# %%
test_l= np.array(test_label.astype('float32'))

# %%
train_l= np.array(train_label.astype('float32'))

# %%
train.shape[1]
# Out:
# 193

# %%
(141,192)[1]
# Out:
# 192

# %%
train.dtype
# Out:
# dtype('float32')

# %% [markdown]
# # Models section
# ```
# #WE will configure different models here according to relu, tanh , regularization, dropout etc..
# ```

# %%
# we are passing activation function as a parameter here so that we can call this function with tanh or relu while
# fitting and training the model
from keras import models
from keras import layers
def build_model(act):
  model = models.Sequential()
  model.add(layers.Dense(128, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dense(64, activation= act))
  model.add(layers.Dense(32, activation= act))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model('relu').summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               24832
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,201
# Trainable params: 35,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
build_model('tanh').summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               24832
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 35,201
# Trainable params: 35,201
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Regularized model
from keras import regularizers
def build_model_regular(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001),input_shape=(train.shape[1],)))
  model.add(layers.Dense(8, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(6, activation= act,kernel_regularizer= regularizers.l1_l2(l1=0.001, l2=0.001)))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_regular('tanh').summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 10)                1940
# _________________________________________________________________
# dense_9 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_10 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,089
# Trainable params: 2,089
# Non-trainable params: 0
# _________________________________________________________________

# %%
# dropout model
from keras import regularizers
def build_model_drop(act):
  model = models.Sequential()
  model.add(layers.Dense(10, activation= act,input_shape=(train.shape[1],)))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(8, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(6, activation= act))
  model.add(layers.Dropout(0.2))
  model.add(layers.Dense(1))
  model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
  return model

# %%
build_model_drop('relu').summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                1940
# _________________________________________________________________
# dropout (Dropout)            (None, 10)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_14 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6)                 0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 2,089
# Trainable params: 2,089
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # K Fold validation section
# ## here we will use len(train)//k to make 141//4 = 36 rows for validation in each validation test and collect the validation scores for relu , tanh , regularization , and dropout

# %%
#k fold validation with relu
# 141/4
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_relu = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_relu.append(val_mae)
# Out:
# processing fold # 0
# processing fold # 1
# processing fold # 2
# processing fold # 3

# %%
# 141/4
#k fold validation with tanh
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_tanh = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model('tanh')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_tanh.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:5 out of the last 9 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b221dd0e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b21113200> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b222c1dd0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b27f44c20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with regularization
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_regular = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_regular('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=0)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=0)
  all_scores_regular.append(val_mae)
# Out:
# processing fold # 0
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b2197df80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 1
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b1feddb00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 2
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b2454c560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# processing fold # 3
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b210f63b0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
#k-fold validtion with dropout
import numpy as np
k =  4
num_val_samples = len(train) // k
num_epochs = 100
all_scores_drop = []
for i in range(k):
  print('processing fold #', i)
  val_data = train[i * num_val_samples: (i + 1) * num_val_samples]
  val_targets = train_l[i * num_val_samples: (i + 1) * num_val_samples]
  partial_train_data = np.concatenate([train[:i * num_val_samples],train[(i + 1) * num_val_samples:]],  axis=0)
  # print(partial_train_data)
  partial_train_targets = np.concatenate([train_l[:i * num_val_samples],train_l[(i + 1) * num_val_samples:]],axis=0)
  model = build_model_drop('relu')
  model.fit(partial_train_data, partial_train_targets,epochs=num_epochs, batch_size=1, verbose=1)
  val_mse, val_mae = model.evaluate(val_data, val_targets, verbose=1)
  all_scores_drop.append(val_mae)
# Out:
# processing fold # 0
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.4538 - mae: 0.9234
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9605 - mae: 0.7363
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8871 - mae: 0.7190
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5479 - mae: 0.5397
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7764 - mae: 0.6349
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1576 - mae: 0.7809
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0219 - mae: 0.6833
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4471 - mae: 0.4679
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8794 - mae: 0.5815
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7495 - mae: 0.5338
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6946 - mae: 0.5428
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4118 - mae: 0.4221
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4016 - mae: 0.4213
# Epoch 14/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5026 - mae: 0.4394
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4440 - mae: 0.4157
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3865 - mae: 0.4139
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4137 - mae: 0.4402
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4042 - mae: 0.3991
# Epoch 19/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5825 - mae: 0.4548
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3786 - mae: 0.4322
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5775 - mae: 0.4584
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4037 - mae: 0.3918
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3393 - mae: 0.3447
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3016 - mae: 0.3802
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4991 - mae: 0.4498
# Epoch 26/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.7929 - mae: 0.4970
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3172 - mae: 0.3679
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3597 - mae: 0.4115
# Epoch 29/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5447 - mae: 0.4468
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6310 - mae: 0.4808
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5549 - mae: 0.4702
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3694 - mae: 0.3904
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5003 - mae: 0.4154
# Epoch 34/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3148 - mae: 0.3952
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2765 - mae: 0.3428
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2207 - mae: 0.2996
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2352 - mae: 0.3196
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6053 - mae: 0.4773
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2497 - mae: 0.3214
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5049 - mae: 0.4152
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2692 - mae: 0.3328
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7380 - mae: 0.4626
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1674 - mae: 0.3016
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2730 - mae: 0.3057
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6261 - mae: 0.4248
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4435 - mae: 0.4332
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5507 - mae: 0.4293
# Epoch 48/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2758 - mae: 0.3346
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3901 - mae: 0.3884
# Epoch 50/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3624 - mae: 0.3541
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4462 - mae: 0.3921
# Epoch 52/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5679 - mae: 0.3764
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2647 - mae: 0.3325
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5993 - mae: 0.4254
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2147 - mae: 0.3089
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3034 - mae: 0.3664
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6096 - mae: 0.4157
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2882 - mae: 0.3399
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3350 - mae: 0.3207
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4841 - mae: 0.3621
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8626 - mae: 0.4914
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7356 - mae: 0.5216
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5968 - mae: 0.4184
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4520 - mae: 0.4060
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4123 - mae: 0.3697
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3978 - mae: 0.3296
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1994 - mae: 0.2944
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1795 - mae: 0.2707
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3048 - mae: 0.3444
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2308 - mae: 0.3063
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3140 - mae: 0.3094
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3658 - mae: 0.3927
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4926 - mae: 0.3909
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3709 - mae: 0.3458
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8789 - mae: 0.5354
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9301 - mae: 0.5162
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2461 - mae: 0.3304
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2050 - mae: 0.2509
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8247 - mae: 0.4928
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2975 - mae: 0.3120
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3202 - mae: 0.2999
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4310 - mae: 0.3892
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1968 - mae: 0.3028
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8650 - mae: 0.4540
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2118 - mae: 0.2899
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3899 - mae: 0.4014
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5589 - mae: 0.3891
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4007 - mae: 0.2928
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5731 - mae: 0.3829
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3148 - mae: 0.3443
# Epoch 91/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3908 - mae: 0.3856
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4815 - mae: 0.3475
# Epoch 93/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4669 - mae: 0.3878
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3505 - mae: 0.3829
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3172 - mae: 0.4073
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5161 - mae: 0.3922
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2688 - mae: 0.3619
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1837 - mae: 0.2974
# Epoch 99/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4569 - mae: 0.3967
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5496 - mae: 0.3579
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b23173950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3577 - mae: 0.4499
# processing fold # 1
# Epoch 1/100
# 106/106 [==============================] - 1s 2ms/step - loss: 2.2705 - mae: 1.1674
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7833 - mae: 0.6642
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7462 - mae: 0.6073
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6011 - mae: 0.5410
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8956 - mae: 0.6090
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6407 - mae: 0.5438
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5774 - mae: 0.5131
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6629 - mae: 0.4852
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4473 - mae: 0.4727
# Epoch 10/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7448 - mae: 0.5416
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3672 - mae: 0.3895
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4125 - mae: 0.4180
# Epoch 13/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3339 - mae: 0.4007
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2950 - mae: 0.3943
# Epoch 15/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3071 - mae: 0.3801
# Epoch 16/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2606 - mae: 0.3683
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7987 - mae: 0.6180
# Epoch 18/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3556 - mae: 0.4135
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3532 - mae: 0.3999
# Epoch 20/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2173 - mae: 0.3377
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4098 - mae: 0.3857
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3581 - mae: 0.3754
# Epoch 23/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3893 - mae: 0.4257
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3358 - mae: 0.3572
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3342 - mae: 0.3400
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3262 - mae: 0.3827
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3433 - mae: 0.3715
# Epoch 28/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2972 - mae: 0.3815
# Epoch 29/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3746 - mae: 0.4194
# Epoch 30/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2205 - mae: 0.3614
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2187 - mae: 0.3652
# Epoch 32/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2545 - mae: 0.3711
# Epoch 33/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3418 - mae: 0.3739
# Epoch 34/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2272 - mae: 0.3712
# Epoch 35/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1994 - mae: 0.2860
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5422 - mae: 0.4940
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2909 - mae: 0.3771
# Epoch 38/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6471 - mae: 0.4635
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2396 - mae: 0.3481
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1858 - mae: 0.2879
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2609 - mae: 0.3216
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5381 - mae: 0.4493
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3021 - mae: 0.3717
# Epoch 44/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2378 - mae: 0.3547
# Epoch 45/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3246 - mae: 0.4072
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2651 - mae: 0.3261
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1727 - mae: 0.2959
# Epoch 48/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2269 - mae: 0.3316
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1861 - mae: 0.3513
# Epoch 50/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3121 - mae: 0.3197
# Epoch 51/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2244 - mae: 0.3236
# Epoch 52/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1273 - mae: 0.2663
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3967 - mae: 0.3856
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6605 - mae: 0.4989
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3486 - mae: 0.3591
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1356 - mae: 0.2872
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1671 - mae: 0.2954
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1988 - mae: 0.3302
# Epoch 59/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3112 - mae: 0.3894
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3456 - mae: 0.3683
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2811 - mae: 0.3481
# Epoch 62/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3249 - mae: 0.3637
# Epoch 63/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2347 - mae: 0.3282
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2362 - mae: 0.3296
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2293 - mae: 0.3068
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6252 - mae: 0.4883
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1380 - mae: 0.2360
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2688 - mae: 0.3115
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2536 - mae: 0.3302
# Epoch 70/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3274 - mae: 0.3274
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4589 - mae: 0.4438
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4686 - mae: 0.3897
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4710 - mae: 0.3667
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2092 - mae: 0.3212
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2532 - mae: 0.3215
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4523 - mae: 0.4066
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8763 - mae: 0.5315
# Epoch 78/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2884 - mae: 0.3430
# Epoch 79/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2709 - mae: 0.3142
# Epoch 80/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3647 - mae: 0.3744
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3903 - mae: 0.3414
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2510 - mae: 0.3417
# Epoch 83/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2536 - mae: 0.3468
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2164 - mae: 0.3190
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3667 - mae: 0.4023
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2556 - mae: 0.3479
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2939 - mae: 0.3297
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2119 - mae: 0.2996
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3869 - mae: 0.4216
# Epoch 90/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3407 - mae: 0.3666
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2781 - mae: 0.3454
# Epoch 92/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1760 - mae: 0.2894
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2447 - mae: 0.3385
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2307 - mae: 0.3156
# Epoch 95/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3518 - mae: 0.3345
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3157 - mae: 0.3340
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3891 - mae: 0.4040
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3047 - mae: 0.3442
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2146 - mae: 0.3220
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1813 - mae: 0.2947
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b22b439e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6048 - mae: 0.5323
# processing fold # 2
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 1.6814 - mae: 0.9327
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1542 - mae: 0.7546
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7170 - mae: 0.6190
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8658 - mae: 0.6754
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5816 - mae: 0.5402
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9666 - mae: 0.6764
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.2650 - mae: 0.6973
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9560 - mae: 0.6396
# Epoch 9/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.8143 - mae: 0.5840
# Epoch 10/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4340 - mae: 0.4232
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7804 - mae: 0.5544
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4157 - mae: 0.4625
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8395 - mae: 0.5820
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5897 - mae: 0.5368
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5785 - mae: 0.5018
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4395 - mae: 0.4297
# Epoch 17/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4077 - mae: 0.4493
# Epoch 18/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5397 - mae: 0.4640
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4025 - mae: 0.4540
# Epoch 20/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4230 - mae: 0.4232
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7130 - mae: 0.4818
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7308 - mae: 0.4979
# Epoch 23/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3122 - mae: 0.3727
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6277 - mae: 0.5393
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1941 - mae: 0.3193
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5025 - mae: 0.4178
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4330 - mae: 0.4557
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3790 - mae: 0.4086
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2342 - mae: 0.3150
# Epoch 30/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3710 - mae: 0.4111
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3705 - mae: 0.3846
# Epoch 32/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3853 - mae: 0.4508
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5908 - mae: 0.4650
# Epoch 34/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2925 - mae: 0.3713
# Epoch 35/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2261 - mae: 0.3092
# Epoch 36/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3644 - mae: 0.3830
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3392 - mae: 0.3927
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2649 - mae: 0.3653
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5215 - mae: 0.4482
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5046 - mae: 0.4419
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4346 - mae: 0.3639
# Epoch 42/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2296 - mae: 0.3236
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3676 - mae: 0.3798
# Epoch 44/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6385 - mae: 0.4356
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3121 - mae: 0.3360
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6980 - mae: 0.5473
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4375 - mae: 0.4031
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3361 - mae: 0.3896
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3062 - mae: 0.3544
# Epoch 50/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3606 - mae: 0.3352
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2649 - mae: 0.3592
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5059 - mae: 0.4444
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2421 - mae: 0.3225
# Epoch 54/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2449 - mae: 0.3186
# Epoch 55/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1934 - mae: 0.3059
# Epoch 56/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4251 - mae: 0.3958
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2212 - mae: 0.3447
# Epoch 58/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2181 - mae: 0.3378
# Epoch 59/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3505 - mae: 0.3755
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8628 - mae: 0.4862
# Epoch 61/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3604 - mae: 0.4141
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3648 - mae: 0.3711
# Epoch 63/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2106 - mae: 0.2507
# Epoch 64/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3676 - mae: 0.4112
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1472 - mae: 0.2614
# Epoch 66/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2664 - mae: 0.3898
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1304 - mae: 0.2434
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5135 - mae: 0.3341
# Epoch 69/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2064 - mae: 0.3077
# Epoch 70/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3880 - mae: 0.3962
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4372 - mae: 0.3866
# Epoch 72/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4290 - mae: 0.3711
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2313 - mae: 0.3422
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3892 - mae: 0.4152
# Epoch 75/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4209 - mae: 0.3627
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3080 - mae: 0.3924
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3254 - mae: 0.3932
# Epoch 78/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2658 - mae: 0.3243
# Epoch 79/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3289 - mae: 0.3166
# Epoch 80/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3358 - mae: 0.3133
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2912 - mae: 0.3224
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4137 - mae: 0.3200
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1338 - mae: 0.2378
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3571 - mae: 0.2973
# Epoch 85/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3494 - mae: 0.3459
# Epoch 86/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2486 - mae: 0.3219
# Epoch 87/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3157 - mae: 0.3247
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2887 - mae: 0.3242
# Epoch 89/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.1508 - mae: 0.2658
# Epoch 90/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2468 - mae: 0.3202
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4090 - mae: 0.3983
# Epoch 92/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4150 - mae: 0.3811
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2305 - mae: 0.2708
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4614 - mae: 0.3844
# Epoch 95/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7281 - mae: 0.4798
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3100 - mae: 0.3307
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2334 - mae: 0.3246
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2015 - mae: 0.2828
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3087 - mae: 0.3306
# Epoch 100/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1720 - mae: 0.2788
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b2885f440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4550 - mae: 0.4364
# processing fold # 3
# Epoch 1/100
# 106/106 [==============================] - 1s 1ms/step - loss: 15.0819 - mae: 3.1150
# Epoch 2/100
# 106/106 [==============================] - 0s 1ms/step - loss: 2.3279 - mae: 1.1371
# Epoch 3/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.3581 - mae: 0.7711
# Epoch 4/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.4589 - mae: 0.9331
# Epoch 5/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9192 - mae: 0.6700
# Epoch 6/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.1982 - mae: 0.6944
# Epoch 7/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0165 - mae: 0.6324
# Epoch 8/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8036 - mae: 0.5755
# Epoch 9/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7682 - mae: 0.6315
# Epoch 10/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.7339 - mae: 0.5799
# Epoch 11/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6728 - mae: 0.5636
# Epoch 12/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6454 - mae: 0.5438
# Epoch 13/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4993 - mae: 0.4539
# Epoch 14/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5692 - mae: 0.5282
# Epoch 15/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4541 - mae: 0.4598
# Epoch 16/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4538 - mae: 0.4490
# Epoch 17/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.9080 - mae: 0.5516
# Epoch 18/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5748 - mae: 0.5090
# Epoch 19/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.9609 - mae: 0.6139
# Epoch 20/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4691 - mae: 0.4517
# Epoch 21/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5266 - mae: 0.5057
# Epoch 22/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5004 - mae: 0.4175
# Epoch 23/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7073 - mae: 0.5608
# Epoch 24/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3887 - mae: 0.4316
# Epoch 25/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3954 - mae: 0.4466
# Epoch 26/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5913 - mae: 0.4974
# Epoch 27/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6552 - mae: 0.5728
# Epoch 28/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3012 - mae: 0.3980
# Epoch 29/100
# 106/106 [==============================] - 0s 1ms/step - loss: 1.0071 - mae: 0.5881
# Epoch 30/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3307 - mae: 0.3948
# Epoch 31/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3447 - mae: 0.3781
# Epoch 32/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4183 - mae: 0.3872
# Epoch 33/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3706 - mae: 0.4357
# Epoch 34/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5709 - mae: 0.5144
# Epoch 35/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3242 - mae: 0.3912
# Epoch 36/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2210 - mae: 0.3213
# Epoch 37/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7366 - mae: 0.4952
# Epoch 38/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4539 - mae: 0.4575
# Epoch 39/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5397 - mae: 0.5054
# Epoch 40/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.6401 - mae: 0.4441
# Epoch 41/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3635 - mae: 0.3929
# Epoch 42/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.8842 - mae: 0.5523
# Epoch 43/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4629 - mae: 0.4218
# Epoch 44/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3679 - mae: 0.4172
# Epoch 45/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5187 - mae: 0.5129
# Epoch 46/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2811 - mae: 0.3506
# Epoch 47/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3018 - mae: 0.4013
# Epoch 48/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4879 - mae: 0.4266
# Epoch 49/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4718 - mae: 0.4239
# Epoch 50/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.7704 - mae: 0.5307
# Epoch 51/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5613 - mae: 0.4025
# Epoch 52/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2184 - mae: 0.3303
# Epoch 53/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2826 - mae: 0.3807
# Epoch 54/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3401 - mae: 0.3728
# Epoch 55/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2849 - mae: 0.3734
# Epoch 56/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2615 - mae: 0.3492
# Epoch 57/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4438 - mae: 0.4054
# Epoch 58/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5598 - mae: 0.4147
# Epoch 59/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4740 - mae: 0.4177
# Epoch 60/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5806 - mae: 0.4504
# Epoch 61/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.6385 - mae: 0.5030
# Epoch 62/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2520 - mae: 0.3296
# Epoch 63/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4836 - mae: 0.4506
# Epoch 64/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.8288 - mae: 0.5729
# Epoch 65/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4480 - mae: 0.3779
# Epoch 66/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5982 - mae: 0.4791
# Epoch 67/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5437 - mae: 0.4082
# Epoch 68/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2989 - mae: 0.3747
# Epoch 69/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.9612 - mae: 0.5184
# Epoch 70/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3028 - mae: 0.3610
# Epoch 71/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3120 - mae: 0.3504
# Epoch 72/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3465 - mae: 0.3818
# Epoch 73/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3002 - mae: 0.3552
# Epoch 74/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4550 - mae: 0.4238
# Epoch 75/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.3796 - mae: 0.4148
# Epoch 76/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5554 - mae: 0.4760
# Epoch 77/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2210 - mae: 0.2965
# Epoch 78/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5276 - mae: 0.4280
# Epoch 79/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5495 - mae: 0.4713
# Epoch 80/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2678 - mae: 0.3681
# Epoch 81/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2910 - mae: 0.3564
# Epoch 82/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1722 - mae: 0.2741
# Epoch 83/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5763 - mae: 0.4642
# Epoch 84/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4115 - mae: 0.3712
# Epoch 85/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4372 - mae: 0.3888
# Epoch 86/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.2093 - mae: 0.3201
# Epoch 87/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4322 - mae: 0.3508
# Epoch 88/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2641 - mae: 0.3343
# Epoch 89/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.5713 - mae: 0.4462
# Epoch 90/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3632 - mae: 0.3501
# Epoch 91/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.5886 - mae: 0.4629
# Epoch 92/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2795 - mae: 0.3018
# Epoch 93/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3393 - mae: 0.3428
# Epoch 94/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.3660 - mae: 0.3578
# Epoch 95/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4059 - mae: 0.3771
# Epoch 96/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2121 - mae: 0.3075
# Epoch 97/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.1664 - mae: 0.2792
# Epoch 98/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.2657 - mae: 0.3620
# Epoch 99/100
# 106/106 [==============================] - 0s 1ms/step - loss: 0.4914 - mae: 0.4248
# Epoch 100/100
# 106/106 [==============================] - 0s 2ms/step - loss: 0.4295 - mae: 0.4439
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b27f44cb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 6ms/step - loss: 0.1001 - mae: 0.2670

# %% [markdown]
# # Scores
# ## here we will see  MAE mean absolute Error scores of all model which we have saved in the list during each training in above section

# %%
all_scores_relu
# Out:
# [0.2853870391845703,
#  0.2970903813838959,
#  0.34351861476898193,
#  0.18110911548137665]

# %%
all_scores_tanh
# Out:
# [0.313093900680542,
#  0.2786778211593628,
#  0.39908871054649353,
#  0.17489676177501678]

# %%
all_scores_regular
# Out:
# [0.22464126348495483,
#  0.203999325633049,
#  0.4061605632305145,
#  0.2827194631099701]

# %%
all_scores_drop
# Out:
# [0.44989341497421265,
#  0.5323481559753418,
#  0.436373233795166,
#  0.26696380972862244]

# %% [markdown]
# # training on the training data
# ## here we will call each model separately from Models section and train on the training data and evaluate on the test data

# %%
model_tanh = build_model('tanh')
model_tanh.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_tanh.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b2078fcb0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 7ms/step - loss: 0.0717 - mae: 0.2062

# %%
model_relu = build_model('relu')
model_relu.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_relu.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b23d0f950> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0783 - mae: 0.2326

# %%
model_regular = build_model_regular('relu')
model_regular.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_regular.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b23d0fb90> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 8ms/step - loss: 0.1475 - mae: 0.2496

# %%
model_drop = build_model_drop('relu')
model_drop.fit(train, train_l,epochs= 100, batch_size=1, verbose=0)
test_mse_score, test_mae_score = model_drop.evaluate(test, test_l)
# Out:
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_test_function.<locals>.test_function at 0x7f4b23476440> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 10ms/step - loss: 0.1669 - mae: 0.3121

# %% [markdown]
# # Prediction Section
# ## here we will predict our prices of our test dataset with each model which we have trained in training section
# ## Note that here we will use the reverse process of Normalization to retrieve our values of price in thousand of dollars i.e. x = (y - mean)/ std ==>> we will calculate( y = x * std + mean) and then we will compare it with our target values

# %% [markdown]
# # New section

# %%
test_l
# Out:
# array([ 0.01414832,  0.3725343 ,  1.3658801 ,  2.122337  , -1.004718  ,
#        -0.7045773 , -0.5886972 , -0.97443527, -0.763189  , -0.52312535,
#        -0.05301089, -0.3704908 , -0.5449216 , -0.80397296, -0.5536523 ,
#        -0.26059392,  0.6062484 ,  1.4864004 ,  2.5404336 ,  3.367835  ,
#        -0.8779702 , -0.09159691,  0.18192424, -0.7802841 , -0.50065756,
#        -0.9622245 , -0.6813769 , -0.5409531 ,  0.01463675,  0.12453365,
#         0.46643507, -0.1806134 ,  0.2687428 ,  0.4299249 ,  0.45129374,
#        -0.07511237,  2.3382235 ,  2.200547  , -0.49870384,  0.20280465,
#         0.26019526, -0.68430746, -0.7224051 , -0.65524584, -0.98066276,
#        -0.7889537 , -0.7547636 , -0.6888255 , -0.6277716 , -0.4983375 ,
#        -0.6020069 , -0.4139611 , -0.22347318, -0.54107517,  0.28217462,
#        -0.68430746, -0.6574438 , -0.59638995, -0.01027321,  0.056886  ,
#        -0.1329914 , -0.05362143,  0.3181964 ,  0.6155285 ], dtype=float32)

# %%
def predict(model, m):
  print(f" the Actual value Price was : {test_l[m]* std_label + mean_label} " )
  return(f" the predicted Price was : {(model.predict(test[m:m+1].reshape(1,test.shape[1]))) * std_label + mean_label} ")

# %%
x_tanh = predict(model_tanh,2)
x_tanh
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21313.648]] '

# %%
x_relu = predict(model_relu,2)
x_relu
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[21843.273]] '

# %%
x_regular = predict(model_regular,2)
x_regular
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[23434.473]] '

# %%
x_drop = predict(model_drop,2)
x_drop
# Out:
#  the Actual value Price was : 24565.000309357743
# ' the predicted Price was : [[20481.695]] '

# %%
def plot_fn(mod):
  y_true = test_l* std_label + mean_label
  y_pred = mod.predict(test) * std_label + mean_label
  return y_true , y_pred.flatten()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
def plotting(mod, label):
  y_true, y_pred = plot_fn(mod)
  coef = np.polyfit(y_true,y_pred,1)
  poly1d_fn = np.poly1d(coef) 
  # poly1d_fn is now a function which takes in x and returns an estimate for y
  plt.figure()
  plt.plot(y_true,y_pred, 'yo', y_true, poly1d_fn(y_true), '--k')
  plt.title(label)
  plt.xlabel('Thousand Dollar True' )
  plt.ylabel('Thousand Dollar Predictions' )
  plt.xlim(0, 50000)
  plt.ylim(0, 50000)

# %%
plot_list = []
for i,j in enumerate([model_relu, model_tanh, model_regular, model_drop]):
  list_name = ['model_relu', 'model_tanh', 'model_regular', 'model_drop']
  plot_list.append(plotting(j,list_name[i]))
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4b3c69f320> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 7 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4b231def80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 9 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4b287bb170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f4b22b439e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
